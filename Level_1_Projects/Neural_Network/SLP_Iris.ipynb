# %% [markdown]
# #  SLP vs MLP on Breast Cancer Dataset
#
# This project compares:
# - **SLP (Single Layer Perceptron)** — a linear classifier
# - **MLP (Multi Layer Perceptron)** — a deep neural network classifier
#
# using the Breast Cancer Wisconsin Diagnostic dataset.
# The objective is to evaluate how adding hidden layers improves classification performance on a **non-linearly separable dataset**.
#
# We will:
# 1. Load and preprocess the dataset
# 2. Train an SLP and an MLP model
# 3. Compare their performance using accuracy, F1-score, and confusion matrix
# 4. Summarize the results

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
slp = Perceptron(max_iter=1000, random_state=42)
slp.fit(X_train, y_train)

y_pred_slp = slp.predict(X_test)
acc_slp = accuracy_score(y_test, y_pred_slp)
f1_slp = f1_score(y_test, y_pred_slp)

print(f"SLP Accuracy: {acc_slp:.4f}")
print(f"SLP F1-Score: {f1_slp:.4f}")
print("\nSLP Classification Report:")
print(classification_report(y_test, y_pred_slp))
# Out:
# SLP Accuracy: 0.9825
# SLP F1-Score: 0.9860
#
# SLP Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98        64
#            1       0.98      0.99      0.99       107
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %%
mlp = MLPClassifier(hidden_layer_sizes=(64, 32), 
                    activation='relu', 
                    solver='adam', 
                    max_iter=1000, 
                    random_state=42)
mlp.fit(X_train, y_train)

y_pred_mlp = mlp.predict(X_test)
acc_mlp = accuracy_score(y_test, y_pred_mlp)
f1_mlp = f1_score(y_test, y_pred_mlp)

print(f"MLP Accuracy: {acc_mlp:.4f}")
print(f"MLP F1-Score: {f1_mlp:.4f}")
print("\nMLP Classification Report:")
print(classification_report(y_test, y_pred_mlp))
# Out:
# MLP Accuracy: 0.9766
# MLP F1-Score: 0.9811
#
# MLP Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97        64
#            1       0.99      0.97      0.98       107
#
#     accuracy                           0.98       171
#    macro avg       0.97      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

cm_slp = confusion_matrix(y_test, y_pred_slp)
sns.heatmap(cm_slp, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('SLP Confusion Matrix')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

cm_mlp = confusion_matrix(y_test, y_pred_mlp)
sns.heatmap(cm_mlp, annot=True, fmt='d', cmap='Greens', ax=axes[1])
axes[1].set_title('MLP Confusion Matrix')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
performance_df = pd.DataFrame({
    'Model': ['SLP', 'MLP'],
    'Accuracy': [acc_slp, acc_mlp],
    'F1-Score': [f1_slp, f1_mlp]
})
display(performance_df)
# Out:
#   Model  Accuracy  F1-Score
# 0   SLP  0.982456  0.986047
# 1   MLP  0.976608  0.981132

# %%
# Step 6: Confusion Matrix Visualization
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred_p), annot=True, fmt='d', cmap='Blues',
            xticklabels=wine.target_names, yticklabels=wine.target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Perceptron Confusion Matrix - Wine Dataset")
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Results Summary
#
# | Metric          | SLP           | MLP           |
# |-----------------|---------------|---------------|
# | Accuracy        | 0.9825        | 0.9766        |
# | F1-Score        | 0.9860        | 0.9811        |
#
#  **Key Insights:**
# - Both models achieved excellent performance on this dataset.
# - SLP slightly outperformed MLP — a reminder that more complex models don’t always guarantee better results.
# - When data is **well structured and linearly separable**, simple models can match or beat deep networks.
# - MLP may shine more on datasets with **complex non-linear boundaries**.
#
#  **Conclusion:**
# For this dataset, SLP is **simpler**, **faster**, and performs **marginally better** than MLP.
# However, on more challenging datasets, MLP would likely take the lead.
